# %%
from src.utils import FileManager
people_data = FileManager.from_csv("people.csv")
people = [row for row in people_data]
print(people)
# Out:
# [{'name': 'Aleksei'}, {'name': 'Amine'}, {'name': 'Anna'}, {'name': 'Astha'}, {'name': 'Brigitta'}, {'name': 'Bryan'}, {'name': 'Ena'}, {'name': 'Esra'}, {'name': 'Faranges'}, {'name': 'Frédéric'}, {'name': 'Hamideh'}, {'name': 'Héloïse'}, {'name': 'Imran'}, {'name': 'Intan K.'}, {'name': 'Jens'}, {'name': 'Kristin'}, {'name': 'Michiel'}, {'name': 'Nancy'}, {'name': 'Pierrick'}, {'name': 'Sandrine'}, {'name': 'Tim'}, {'name': 'Viktor'}, {'name': 'Welederufeal'}, {'name': 'Wiktor'}, {'name': 'Živile'}]

# %%
from typing import Any
rows: list[dict[str, Any]] = []

for i in range(4):
    rows.append({
                "Name": i+0,
                "Table": i+1,
                "WithPref": i+2,
                "WithoutPref": i+3,
                "Cluster": i+4
                })
print(rows)
# Out:
# [{'Name': 0, 'Table': 1, 'WithPref': 2, 'WithoutPref': 3, 'Cluster': 4}, {'Name': 1, 'Table': 2, 'WithPref': 3, 'WithoutPref': 4, 'Cluster': 5}, {'Name': 2, 'Table': 3, 'WithPref': 4, 'WithoutPref': 5, 'Cluster': 6}, {'Name': 3, 'Table': 4, 'WithPref': 5, 'WithoutPref': 6, 'Cluster': 7}]

# %%
[r['WithoutPref'] for r in rows]
# Out:
# [3, 4, 5, 6]
